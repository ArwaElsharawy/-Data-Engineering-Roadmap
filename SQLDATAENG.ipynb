-- %% [markdown]
-- # [DataEng]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DataEng]    Script Date: 2/28/2024 7:59:34 PM ******/
CREATE DATABASE [DataEng]
 CONTAINMENT = NONE
 ON  PRIMARY
( NAME = N'DataEng', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\DataEng.mdf' , SIZE = 73728KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON
( NAME = N'DataEng_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\DataEng_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [DataEng] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DataEng].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DataEng] SET ANSI_NULL_DEFAULT OFF
GO
ALTER DATABASE [DataEng] SET ANSI_NULLS OFF
GO
ALTER DATABASE [DataEng] SET ANSI_PADDING OFF
GO
ALTER DATABASE [DataEng] SET ANSI_WARNINGS OFF
GO
ALTER DATABASE [DataEng] SET ARITHABORT OFF
GO
ALTER DATABASE [DataEng] SET AUTO_CLOSE OFF
GO
ALTER DATABASE [DataEng] SET AUTO_SHRINK OFF
GO
ALTER DATABASE [DataEng] SET AUTO_UPDATE_STATISTICS ON
GO
ALTER DATABASE [DataEng] SET CURSOR_CLOSE_ON_COMMIT OFF
GO
ALTER DATABASE [DataEng] SET CURSOR_DEFAULT  GLOBAL
GO
ALTER DATABASE [DataEng] SET CONCAT_NULL_YIELDS_NULL OFF
GO
ALTER DATABASE [DataEng] SET NUMERIC_ROUNDABORT OFF
GO
ALTER DATABASE [DataEng] SET QUOTED_IDENTIFIER OFF
GO
ALTER DATABASE [DataEng] SET RECURSIVE_TRIGGERS OFF
GO
ALTER DATABASE [DataEng] SET  DISABLE_BROKER
GO
ALTER DATABASE [DataEng] SET AUTO_UPDATE_STATISTICS_ASYNC OFF
GO
ALTER DATABASE [DataEng] SET DATE_CORRELATION_OPTIMIZATION OFF
GO
ALTER DATABASE [DataEng] SET TRUSTWORTHY OFF
GO
ALTER DATABASE [DataEng] SET ALLOW_SNAPSHOT_ISOLATION OFF
GO
ALTER DATABASE [DataEng] SET PARAMETERIZATION SIMPLE
GO
ALTER DATABASE [DataEng] SET READ_COMMITTED_SNAPSHOT OFF
GO
ALTER DATABASE [DataEng] SET HONOR_BROKER_PRIORITY OFF
GO
ALTER DATABASE [DataEng] SET RECOVERY SIMPLE
GO
ALTER DATABASE [DataEng] SET  MULTI_USER
GO
ALTER DATABASE [DataEng] SET PAGE_VERIFY CHECKSUM
GO
ALTER DATABASE [DataEng] SET DB_CHAINING OFF
GO
ALTER DATABASE [DataEng] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF )
GO
ALTER DATABASE [DataEng] SET TARGET_RECOVERY_TIME = 60 SECONDS
GO
ALTER DATABASE [DataEng] SET DELAYED_DURABILITY = DISABLED
GO
ALTER DATABASE [DataEng] SET ACCELERATED_DATABASE_RECOVERY = OFF
GO
ALTER DATABASE [DataEng] SET QUERY_STORE = ON
GO
ALTER DATABASE [DataEng] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Admission Table]

-- %%
USE [DataEng]
GO

-- %%
/****** Object:  Table [dbo].[Admission Table]    Script Date: 2/28/2024 7:59:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Admission Table](
	[Patient_ID] [smallint] NOT NULL,
	[Hospital_ID] [smallint] NOT NULL,
	[Admission_Type] [nvarchar](50) NOT NULL,
	[Date_of_Admission] [date] NOT NULL,
	[Discharge_Date] [date] NOT NULL,
	[Room_Number] [smallint] NOT NULL,
 CONSTRAINT [PK_Admission Table] PRIMARY KEY CLUSTERED
(
	[Patient_ID] ASC,
	[Hospital_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cure Table]

-- %%
/****** Object:  Table [dbo].[Cure Table]    Script Date: 2/28/2024 7:59:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cure Table](
	[Patient_ID] [smallint] NOT NULL,
	[Doctors_ID] [smallint] NOT NULL,
	[Hospital_ID] [smallint] NOT NULL,
	[Medication] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Cure Table] PRIMARY KEY CLUSTERED
(
	[Patient_ID] ASC,
	[Doctors_ID] ASC,
	[Hospital_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Diagnosed Table (1)]

-- %%
/****** Object:  Table [dbo].[Diagnosed Table (1)]    Script Date: 2/28/2024 7:59:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Diagnosed Table (1)](
	[Patient_ID] [smallint] NOT NULL,
	[Doctors_ID] [smallint] NOT NULL,
	[Hospital_ID] [smallint] NOT NULL,
	[Medical_Condition] [nvarchar](50) NOT NULL,
	[Test_Results] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Diagnosed Table (1)] PRIMARY KEY CLUSTERED
(
	[Patient_ID] ASC,
	[Doctors_ID] ASC,
	[Hospital_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Doctor Table]

-- %%
/****** Object:  Table [dbo].[Doctor Table]    Script Date: 2/28/2024 7:59:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Doctor Table](
	[Doctors_ID] [smallint] NOT NULL,
	[Doctor] [nvarchar](50) NOT NULL,
	[Hospital_ID] [smallint] NOT NULL,
 CONSTRAINT [PK_Doctor Table] PRIMARY KEY CLUSTERED
(
	[Doctors_ID] ASC,
	[Hospital_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[filtered Table]

-- %%
/****** Object:  Table [dbo].[filtered Table]    Script Date: 2/28/2024 7:59:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[filtered Table](
	[Name] [nvarchar](50) NOT NULL,
	[Age] [tinyint] NOT NULL,
	[Gender] [nvarchar](50) NOT NULL,
	[Blood_Type] [nvarchar](50) NOT NULL,
	[Medical_Condition] [nvarchar](50) NOT NULL,
	[Date_of_Admission] [date] NOT NULL,
	[Doctor] [nvarchar](50) NOT NULL,
	[Hospital] [nvarchar](50) NOT NULL,
	[Insurance_Provider] [nvarchar](50) NOT NULL,
	[Billing_Amount] [float] NULL,
	[Room_Number] [smallint] NOT NULL,
	[Admission_Type] [nvarchar](50) NOT NULL,
	[Discharge_Date] [date] NOT NULL,
	[Medication] [nvarchar](50) NOT NULL,
	[Test_Results] [nvarchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Hospitals Table]

-- %%
/****** Object:  Table [dbo].[Hospitals Table]    Script Date: 2/28/2024 7:59:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Hospitals Table](
	[Name] [nvarchar](50) NOT NULL,
	[Hospital_ID] [smallint] NOT NULL,
 CONSTRAINT [PK_Hospitals Table] PRIMARY KEY CLUSTERED
(
	[Hospital_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Patient Table]

-- %%
/****** Object:  Table [dbo].[Patient Table]    Script Date: 2/28/2024 7:59:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Patient Table](
	[Patient_ID] [smallint] NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Age] [tinyint] NOT NULL,
	[Gender] [nvarchar](50) NOT NULL,
	[Blood_Type] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Patient Table] PRIMARY KEY CLUSTERED
(
	[Patient_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Payment Table]

-- %%
/****** Object:  Table [dbo].[Payment Table]    Script Date: 2/28/2024 7:59:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Payment Table](
	[Patient_ID] [smallint] NOT NULL,
	[Hospital_ID] [smallint] NOT NULL,
	[Billing_Amount] [float] NOT NULL,
	[Insurance_Provider] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Payment Table] PRIMARY KEY CLUSTERED
(
	[Patient_ID] ASC,
	[Hospital_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Admission Table_Hospitals Table]

-- %%
ALTER TABLE [dbo].[Admission Table]  WITH CHECK ADD  CONSTRAINT [FK_Admission Table_Hospitals Table] FOREIGN KEY([Hospital_ID])
REFERENCES [dbo].[Hospitals Table] ([Hospital_ID])
GO
ALTER TABLE [dbo].[Admission Table] CHECK CONSTRAINT [FK_Admission Table_Hospitals Table]
GO

-- %% [markdown]
-- # [FK_Admission Table_Patient Table]

-- %%
ALTER TABLE [dbo].[Admission Table]  WITH CHECK ADD  CONSTRAINT [FK_Admission Table_Patient Table] FOREIGN KEY([Patient_ID])
REFERENCES [dbo].[Patient Table] ([Patient_ID])
GO
ALTER TABLE [dbo].[Admission Table] CHECK CONSTRAINT [FK_Admission Table_Patient Table]
GO

-- %% [markdown]
-- # [FK_Cure Table_Doctor Table]

-- %%
ALTER TABLE [dbo].[Cure Table]  WITH CHECK ADD  CONSTRAINT [FK_Cure Table_Doctor Table] FOREIGN KEY([Doctors_ID], [Hospital_ID])
REFERENCES [dbo].[Doctor Table] ([Doctors_ID], [Hospital_ID])
GO
ALTER TABLE [dbo].[Cure Table] CHECK CONSTRAINT [FK_Cure Table_Doctor Table]
GO

-- %% [markdown]
-- # [FK_Cure Table_Patient Table]

-- %%
ALTER TABLE [dbo].[Cure Table]  WITH CHECK ADD  CONSTRAINT [FK_Cure Table_Patient Table] FOREIGN KEY([Patient_ID])
REFERENCES [dbo].[Patient Table] ([Patient_ID])
GO
ALTER TABLE [dbo].[Cure Table] CHECK CONSTRAINT [FK_Cure Table_Patient Table]
GO

-- %% [markdown]
-- # [FK_Diagnosed Table (1)_Doctor Table]

-- %%
ALTER TABLE [dbo].[Diagnosed Table (1)]  WITH CHECK ADD  CONSTRAINT [FK_Diagnosed Table (1)_Doctor Table] FOREIGN KEY([Doctors_ID], [Hospital_ID])
REFERENCES [dbo].[Doctor Table] ([Doctors_ID], [Hospital_ID])
GO
ALTER TABLE [dbo].[Diagnosed Table (1)] CHECK CONSTRAINT [FK_Diagnosed Table (1)_Doctor Table]
GO

-- %% [markdown]
-- # [FK_Diagnosed Table (1)_Patient Table]

-- %%
ALTER TABLE [dbo].[Diagnosed Table (1)]  WITH CHECK ADD  CONSTRAINT [FK_Diagnosed Table (1)_Patient Table] FOREIGN KEY([Patient_ID])
REFERENCES [dbo].[Patient Table] ([Patient_ID])
GO
ALTER TABLE [dbo].[Diagnosed Table (1)] CHECK CONSTRAINT [FK_Diagnosed Table (1)_Patient Table]
GO

-- %% [markdown]
-- # [FK_Doctor Table_Hospitals Table]

-- %%
ALTER TABLE [dbo].[Doctor Table]  WITH CHECK ADD  CONSTRAINT [FK_Doctor Table_Hospitals Table] FOREIGN KEY([Hospital_ID])
REFERENCES [dbo].[Hospitals Table] ([Hospital_ID])
GO
ALTER TABLE [dbo].[Doctor Table] CHECK CONSTRAINT [FK_Doctor Table_Hospitals Table]
GO

-- %% [markdown]
-- # [FK_Payment Table_Hospitals Table]

-- %%
ALTER TABLE [dbo].[Payment Table]  WITH CHECK ADD  CONSTRAINT [FK_Payment Table_Hospitals Table] FOREIGN KEY([Hospital_ID])
REFERENCES [dbo].[Hospitals Table] ([Hospital_ID])
GO
ALTER TABLE [dbo].[Payment Table] CHECK CONSTRAINT [FK_Payment Table_Hospitals Table]
GO

-- %% [markdown]
-- # [FK_Payment Table_Patient Table]

-- %%
ALTER TABLE [dbo].[Payment Table]  WITH CHECK ADD  CONSTRAINT [FK_Payment Table_Patient Table] FOREIGN KEY([Patient_ID])
REFERENCES [dbo].[Patient Table] ([Patient_ID])
GO
ALTER TABLE [dbo].[Payment Table] CHECK CONSTRAINT [FK_Payment Table_Patient Table]
GO

-- %% [markdown]
-- # [DataEng]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DataEng] SET  READ_WRITE
GO
